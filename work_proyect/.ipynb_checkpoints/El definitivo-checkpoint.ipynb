# %% [markdown]
# # 1.Exploración de los datos

# %% [markdown]
# **Comenzamos importando la tablas y las librerías.**

# %%
import pandas as pd
import numpy as np
import os
import re
from IPython.display import display

#chequear el dataset
os.chdir("../Imputs")
dataset = pd.read_csv("raw_data.csv",engine= "python")

# %%
dataset.shape
# Out:
# (25723, 24)

# %% [raw]
# dataset.info

# %%
dataset.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# *Con esta información nos hacemos una idea del número de columnas y filas(25723, 24). Y nos damos cuenta que no todas las columnas tienen el mismo número de filas.
#
# *Comprobamos que todas las columnas son objetos (string) a excepcion de dos.

# %% [markdown]
# **Para tener una visión más clara, imprimimos la tabla sin límite de líneas**

# %%
pd.options.display.max_columns = 500

# %% [markdown]
# *A primer vistazo encontramos espacios en blancos en las celdas que estropean el diseño.
#
# *Case Number y Date, pese a tener formatos diferentes, parecen tener informacion similar.
#
# *Las columnas pdf, href e investigator or source no aportan valor al análisis.
#
# *Case Number, que es una de las columnas con más datos tiene una especie de índices 0 en su cola.
#
# *En Name, hay elementos que deberían ir en Sex.

# %% [markdown]
# **Comprobamos la cantidad de elementos con los que nos encontramos**

# %%
dataset.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# *Vemos que Unnamed:22 y 23 tienen casi todas las Nam (con respecto a las 5992 que vemos en .info).
#
# *La columna Time tiene más de la mitad Nam.
#
# *Y la columna Name Y Species se acercan a la mitad.

# %% [markdown]
# **Chequearemos si las columnas son únicas o están duplicadas**

# %%
dataset.apply(lambda x: x.nunique())
# Out:
# Case Number               6287
# Date                      5433
# Year                       249
# Type                         8
# Country                    212
# Area                       825
# Location                  4108
# Activity                  1532
# Name                      5230
# Sex                          6
# Age                        157
# Injury                    3737
# Fatal (Y/N)                  8
# Time                       366
# Species                   1549
# Investigator or Source    4969
# pdf                       6291
# href formula              6290
# href                      6285
# Case Number.1             6285
# Case Number.2             6286
# original order            6308
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %% [markdown]
# *Parece interesante 9 valores diferentes en Y/N que solo admite 2.
#
# *También en Age hay 157 valores diferentes y es d extrañar que una persona pueda vivir tanto.
#
# *Con Sex sucede lo mismo, no existen 6 sexos por ahora.

# %% [markdown]
# # 2.Limpieza de Datos

# %% [markdown]
# **Cambiar las columnas diferentes a object a object para poder utilizar Redex.**

# %%
dataset[["Year","original order"]]=dataset[["Year","original order"]].astype(str)

# %% [markdown]
# **Borrar los espacios de los nombres de las columnas.**

# %%
dataset.rename(columns={'Sex ':"Sex",'Species ':"Species"})
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     nan         NaN        NaN
# 25719         NaN          NaN     nan         NaN        NaN
# 25720         NaN          NaN     nan         NaN        NaN
# 25721         NaN          NaN     nan         NaN        NaN
# 25722          xx          NaN     nan         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# **Borrar espacios de las celdas.**

# %%
dataset_trimmed=dataset.apply(lambda x:x.str.strip())

# %% [markdown]
# **Chequear de los pocos valores que quedan sin ser nulos en Unamed:23 y 23 tienen algún sentido.**

# %%
dataset[(dataset["Unnamed: 22"].isnull()==False) | (dataset["Unnamed: 23"].isnull()==False)]
# Out:
#        Case Number                  Date    Year        Type  \
# 1478    2006.05.27           27-May-2006  2006.0  Unprovoked
# 4415    1952.03.30           30-Mar-1952  1952.0  Unprovoked
# 5840  1878.09.14.R  Reported 14-Sep-1878  1878.0    Provoked
#
#                    Country         Area                    Location  \
# 1478                   USA       Hawaii          North Shore, O'ahu
# 4415  NETHERLANDS ANTILLES      Curacao                         NaN
# 5840                   USA  Connecticut  Branford, New Haven County
#
#                                              Activity              Name Sex   \
# 1478                                          Surfing      Bret Desmond    M
# 4415  Went to aid of child being menaced by the shark       A.J. Eggink    M
# 5840                                          Fishing  Captain Pattison    M
#
#       Age                                        Injury Fatal (Y/N)   Time  \
# ...

# %% [markdown]
# *Vemos que quedan tres datos : stopped here, Teramo y change filename, que no aportan ningún valor. Es por ellos que eliminamos ambas columnas.

# %%
dataset.drop(["Unnamed: 22", "Unnamed: 23"], axis=1, inplace=True)
